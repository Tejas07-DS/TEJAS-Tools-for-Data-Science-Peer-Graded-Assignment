# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Tejas Ghoradkar__
#
# Chemical Enginner

# %% [markdown]
# _I am interested in data science because as it solves complex problem in simple manner. Data science is one of the broadest fields available for individuals with a mathematical or statistical background which helps each & every industry to solve thier problems._

# %% [markdown]
# ### The Following Code will Display today's time and date

# %%
import datetime 
message = "Today's Date and Time is " 
print (message , datetime.datetime.now() )
# Out:
# Today's Date and Time is  2023-01-29 20:20:35.302000

# %% [markdown]
# #### My favourite Fruits
# - Apple
# - Mango
# - Orange
# - Watermelon
# - Kiwi

# %% [markdown]
# #### Recently watched movies
# 1. Pathaan
# 2. Avatar: The Way of Water
# 3. Babylon

# %% [markdown]
# ##### You will find photo of this Great warrior in every maharashtrian's house:
# ![Chhatrapati Shivaji Maharaj.jpg](attachment:42394afb-ac3c-49f5-8207-22d6b5f90f53.jpg)

# %% [markdown]
# <center> Chhatrapati Shivaji Maharaj
